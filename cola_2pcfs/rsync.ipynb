# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')

# %%
# %pylab inline
import commands
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/share/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['product', 'random', 'transpose', 'copy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
# !pwd
# Out:
# /home/xiaodongli/projects/cf_pks/cola_2pcfs

# %%
for nowdir in commands.getoutput('ls /public/projects/simulation').split():
    print nowdir
    #!ls /public/projects/simulation/$nowdir/*.2pcf
    # !mkdir $nowdir
    # !rsync -avrP /public/projects/simulation/$nowdir/*.2pcf $nowdir
    # !rsync -avrP /public/projects/simulation/$nowdir/*.sh $nowdir
    # !rsync -avrP /public/projects/simulation/$nowdir/*.lua $nowdir
    # !rsync -avrP /public/projects/simulation/$nowdir/*.py $nowdir
# Out:
# cola_output
# mkdir: cannot create directory ‘cola_output’: File exists
# sending incremental file list
#
# sent 386 bytes  received 12 bytes  796.00 bytes/sec
# total size is 3,339,035  speedup is 8,389.54
# sending incremental file list
#
# sent 273 bytes  received 12 bytes  570.00 bytes/sec
# total size is 12,279  speedup is 43.08
# sending incremental file list
#
# sent 118 bytes  received 12 bytes  260.00 bytes/sec
# total size is 5,219  speedup is 40.15
# sending incremental file list
#
# sent 75 bytes  received 12 bytes  174.00 bytes/sec
# total size is 297  speedup is 3.41
# cola_output_128box_1024c
# mkdir: cannot create directory ‘cola_output_128box_1024c’: File exists
# sending incremental file list
# rsync: link_stat "/public/projects/simulation/cola_output_128box_1024c/*.2pcf" failed: No such file or directory (2)
#
# sent 18 bytes  received 12 bytes  60.00 bytes/sec
# total size is 0  speedup is 0.00
# ...
